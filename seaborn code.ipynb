# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'/content/Students Social Media Addiction.csv')
df
# Out:
#      Student_ID  Age  Gender Academic_Level     Country  \
# 0             1   19  Female  Undergraduate  Bangladesh
# 1             2   22    Male       Graduate       India
# 2             3   20  Female  Undergraduate         USA
# 3             4   18    Male    High School          UK
# 4             5   21    Male       Graduate      Canada
# ..          ...  ...     ...            ...         ...
# 700         701   20  Female  Undergraduate       Italy
# 701         702   23    Male       Graduate      Russia
# 702         703   21  Female  Undergraduate       China
# 703         704   24    Male       Graduate       Japan
# 704         705   19  Female  Undergraduate      Poland
#
#      Avg_Daily_Usage_Hours Most_Used_Platform Affects_Academic_Performance  \
# 0                      5.2          Instagram                          Yes
# 1                      2.1            Twitter                           No
# ...

# %%
sns.set(style = 'darkgrid', rc = {'figure.figsize':(10, 6)}, font_scale = 1.5)

# %%
sns.displot(df['Student_ID'])

# %%
sns.displot
sns.displot(df['Student_ID'], bins = 20)

# %%
sns.displot(df['Student_ID'], kde = False)

# %%
sns.distplot(df['Student_ID'], hist = False, vertical= True, color = 'black')
# Out:
# /tmp/ipython-input-3068898529.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Student_ID'], hist = False, vertical= True, color = 'black')
# <Axes: xlabel='Density', ylabel='Student_ID'>

# %%
sns.jointplot(x = 'Student_id', y = 'df', data = df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-690501914.py in <cell line: 0>()
# ----> 1 sns.jointplot(x = 'Student_id', y = 'df', data = df)
#
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2241
#    2242     # Initialize the JointGrid object
# -> 2243     grid = JointGrid(
#    2244         data=data, x=x, y=y, hue=hue,
#    2245         palette=palette, hue_order=hue_order, hue_norm=hue_norm,
#
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py in __init__(self, data, x, y, hue, height, ratio, space, palette, hue_order, hue_norm, dropna, xlim, ylim, marginal_ticks)
#    1726
#    1727         # Process the input variables
# ...

# %%
sns.jointplot(x = 'Student_ID', y = 'df', data = df, kind = 'hex')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2932530191.py in <cell line: 0>()
# ----> 1 sns.jointplot(x = 'Student_ID', y = 'df', data = df, kind = 'hex')
#
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2241
#    2242     # Initialize the JointGrid object
# -> 2243     grid = JointGrid(
#    2244         data=data, x=x, y=y, hue=hue,
#    2245         palette=palette, hue_order=hue_order, hue_norm=hue_norm,
#
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py in __init__(self, data, x, y, hue, height, ratio, space, palette, hue_order, hue_norm, dropna, xlim, ylim, marginal_ticks)
#    1726
#    1727         # Process the input variables
# ...
